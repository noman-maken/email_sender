# %%
import os
import imghdr
from email.message import EmailMessage
import smtplib, ssl
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

EMAIL_ADDRESS = os.environ.get('EMAIL_USER')
EMAIL_PASSWORD = os.environ.get('EMAIL_PASS')


msg = EmailMessage()
msg['Subject'] = input('Please type Subject here: ')
msg['From'] = "demo@developerszone.site"
msg['To'] = input('Please Enter Email Address: ')

msg.set_content('This is a plain text email')

msg.add_alternative("""\
<table border="5px solid black">
<tr align="center">
	<th>Name</th>
	<th>Class</th>
	<th>City</th>
	<th>Country</th>
</tr>
<tr align="center">
	<td>Muhammad Noman</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Urwa Mubeen</td>
	<td>AIC</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Noman Ahsan</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Atif Hussain</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Shabbir Awan</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
</table>
          
      
""", subtype='html')


with smtplib.SMTP_SSL('developerszone.site', 465) as smtp:
    smtp.login('demo@developerszone.site', 'Demo@1122')
    smtp.send_message(msg)
    print(msg)

# %%
import os
import imghdr
from email.message import EmailMessage
import smtplib, ssl
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

EMAIL_ADDRESS = os.environ.get('EMAIL_USER')
EMAIL_PASSWORD = os.environ.get('EMAIL_PASS')


msg = EmailMessage()
msg['Subject'] = input('Please type Subject here: ')
msg['From'] = EMAIL_ADDRESS
msg['To'] = input('Please Enter Email Address: ')

msg.set_content('This is a plain text email')

msg.add_alternative("""\
<table border="5px solid black">
<tr align="center">
	<th>Name</th>
	<th>Class</th>
	<th>City</th>
	<th>Country</th>
</tr>
<tr align="center">
	<td>Muhammad Noman</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Urwa Mubeen</td>
	<td>AIC</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Noman Ahsan</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Atif Hussain</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
<tr align="center">
	<td>Shabbir Awan</td>
	<td>AI</td>
	<td>Sargodha</td>
	<td>Pakistan</td>
</tr>
</table>
          
      
""", subtype='html')


with smtplib.SMTP_SSL('developerszone.site', 465) as smtp:
    smtp.login('demo@developerszone.site', 'Demo@1122')
    smtp.send_message(msg)
    print(msg)
